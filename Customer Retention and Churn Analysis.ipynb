# %%
import pandas as pd
Churn_data=pd.read_csv(r"C:\Users\DELL 3310\Desktop\Data Science project\WA_Fn-UseC_-Telco-Customer-Churn.csv")
Churn_data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
Churn_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
Churn_data.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
Churn_data.shape
# Out:
# (7043, 21)

# %%
Churn_data.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
#Columns with missing Data
Churn_data.isnull()
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0          False   False          False    False       False   False
# 1          False   False          False    False       False   False
# 2          False   False          False    False       False   False
# 3          False   False          False    False       False   False
# 4          False   False          False    False       False   False
# ...          ...     ...            ...      ...         ...     ...
# 7038       False   False          False    False       False   False
# 7039       False   False          False    False       False   False
# 7040       False   False          False    False       False   False
# 7041       False   False          False    False       False   False
# 7042       False   False          False    False       False   False
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# ...

# %%
Churn_data.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
#blank Strings
(Churn_data=='').sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
#TotalCharges datatype should be a number
Churn_data['TotalCharges'].head()
# Out:
# 0      29.85
# 1     1889.5
# 2     108.15
# 3    1840.75
# 4     151.65
# Name: TotalCharges, dtype: object

# %%
#for blank Spaces
(Churn_data['TotalCharges'] == ' ').sum()
# Out:
# 11

# %%
Churn_data['TotalCharges'] = pd.to_numeric(Churn_data['TotalCharges'], errors='coerce')
Churn_data['TotalCharges'].isnull().sum()
# Out:
# 11

# %%
#Check duplicates
Churn_data.duplicated().sum()
# Out:
# 0

# %%
Churn_data['customerID'].nunique()
# Out:
# 7043

# %%
#Check categories

for col in Churn_data.select_dtypes(include='object'):
    print(col)
# Out:
# customerID
# gender
# Partner
# Dependents
# PhoneService
# MultipleLines
# InternetService
# OnlineSecurity
# OnlineBackup
# DeviceProtection
# TechSupport
# StreamingTV
# StreamingMovies
# Contract
# PaperlessBilling
# PaymentMethod
# Churn

# %%
for col in Churn_data.select_dtypes(include='object'):
    print(col)
    print(Churn_data[col].nunique())
    print()
# Out:
# customerID
# 7043
#
# gender
# 2
#
# Partner
# 2
#
# Dependents
# 2
#
# PhoneService
# 2
#
# MultipleLines
# 3
#
# InternetService
# 3
#
# OnlineSecurity
# 3
#
# OnlineBackup
# 3
#
# DeviceProtection
# 3
#
# TechSupport
# 3
#
# StreamingTV
# 3
#
# StreamingMovies
# 3
#
# Contract
# 3
#
# PaperlessBilling
# 2
#
# PaymentMethod
# 4
#
# Churn
# 2

# %%
Churn_data['Churn'].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
#Lets Check osn visuals now
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Create Boxplots for outliers.
plt.figure(figsize=(7,3))
sns.boxplot(x=Churn_data['MonthlyCharges'])
plt.show()

# %%
plt.figure(figsize=(7,3))
sns.boxplot(x=Churn_data['TotalCharges'])
plt.show()

# %%
#Check Class Balance
Churn_data['Churn'].value_counts(normalize=True)*100
# Out:
# No     73.463013
# Yes    26.536987
# Name: Churn, dtype: float64

# %%
#overal churn rate calculation
churn_counts = Churn_data['Churn'].value_counts()

print(churn_counts)

churn_rate = (churn_counts['Yes'] / len(Churn_data)) * 100

print(f"Churn Rate: {churn_rate:.2f}%")
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64
# Churn Rate: 26.54%

# %%
import matplotlib.pyplot as plt

Churn_data['Churn'].value_counts().plot(
    kind='pie',
    autopct='%1.1f%%',
    figsize=(7,7)
)

plt.title('Customer Churn Distribution')
plt.ylabel('')
plt.show()

# %%
pd.crosstab(Churn_data['Contract'], Churn_data['Churn'], normalize='index')*100
# Out:
# Churn                  No        Yes
# Contract
# Month-to-month  57.290323  42.709677
# One year        88.730482  11.269518
# Two year        97.168142   2.831858

# %%
sns.boxplot(x='Churn', y='MonthlyCharges', data=Churn_data)
plt.show()

# %%
pd.crosstab(Churn_data['TechSupport'], Churn_data['Churn'], normalize='index')*100
# Out:
# Churn                       No        Yes
# TechSupport
# No                   58.364526  41.635474
# No internet service  92.595020   7.404980
# Yes                  84.833659  15.166341

# %%
pd.crosstab(Churn_data['InternetService'], Churn_data['Churn'], normalize='index')*100
# Out:
# Churn                   No        Yes
# InternetService
# DSL              81.040892  18.959108
# Fiber optic      58.107235  41.892765
# No               92.595020   7.404980

# %%
sns.boxplot(
    x='Churn',
    y='tenure',
    data=Churn_data
)

plt.title('Tenure vs Churn')
plt.show()

# %%
print("Average tenure:", Churn_data['tenure'].mean())
print("Median tenure:", Churn_data['tenure'].median())
# Out:
# Average tenure: 32.37114865824223
# Median tenure: 29.0

# %%
# Convert TotalCharges to numeric
Churn_data['TotalCharges'] = pd.to_numeric(
    Churn_data['TotalCharges'],
    errors='coerce'
)

# Remove any resulting nulls if necessary
Churn_data = Churn_data.dropna()

# Remove duplicates if found
Churn_data = Churn_data.drop_duplicates()

# %%
Churn_data.to_csv(
    'clean_churn_data.csv',
    index=False
)

print("Cleaned dataset saved successfully!")
# Out:
# Cleaned dataset saved successfully!

# %%
import os

print(os.getcwd())
# Out:
# C:\Users\DELL 3310\Desktop\Data Science project
